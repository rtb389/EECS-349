# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(1,1,'ro')
plt.plot(4,8,'bx')
plt.plot(5,7,'bx')
plt.plot(2,6,'bx')
plt.plot(6,4,'ro')
plt.plot(8,1,'bx')

plt.axis([0,10,0,10])
plt.title('Original')
plt.savefig('HW8_g1')
plt.show()

# %%
plt.plot(1,1,'ro')
plt.plot(4,8,'bx')
plt.plot(5,7,'bx')
plt.plot(2,6,'bx')
plt.plot(6,4,'ro')
plt.plot(8,1,'bx')
plt.plot([0,10],[5,5],'g-')

plt.axis([0,10,0,10])
plt.title('Round 1')
plt.savefig('HW8_g2')
plt.show()

# %%
plt.plot(1,1,'ro')
plt.plot(4,8,'ro')
plt.plot(5,7,'ro')
plt.plot(2,6,'bx')
plt.plot(6,4,'bx')
plt.plot(8,1,'ro')
plt.plot([3,3],[0,10],'b-')
plt.plot([0,10],[5,5],'g-')

plt.axis([0,10,0,10])
plt.title('Round 2')
plt.savefig('HW8_g3')
plt.show()

# %%
plt.plot(1,1,'bx')
plt.plot(4,8,'ro')
plt.plot(5,7,'ro')
plt.plot(2,6,'ro')
plt.plot(6,4,'bx')
plt.plot(8,1,'ro')
plt.plot([0,10],[5,5],'g-')
plt.plot([3,3],[0,10],'b-')
plt.plot([0,10],[2,2],'r-')

plt.axis([0,10,0,10])
plt.title('Round 3')
plt.savefig('HW8_g4')
plt.show()

# %%
plt.plot(1,1,'bx')
plt.plot(4,8,'ro')
plt.plot(5,7,'ro')
plt.plot(2,6,'ro')
plt.plot(6,4,'ro')
plt.plot(8,1,'bx')
plt.plot([0,10],[5,5],'g-')
plt.plot([3,3],[0,10],'b-')
plt.plot([0,10],[2,2],'r-')

plt.axis([0,10,0,10])
plt.title('Final')
plt.savefig('HW8_g5')
plt.show()

# %%
plt.plot(1,1,'bx')
plt.plot(4,8,'ro')
plt.plot(5,7,'ro')
plt.plot(2,6,'bx')
plt.plot(6,4,'ro')
plt.plot(8,1,'ro')
plt.plot([0,10],[5,5],'g-')
plt.plot([3,3],[0,10],'b-')
plt.plot([0,10],[2,2],'r-')

plt.axis([0,10,0,10])
plt.title('AdaBoost Class')
plt.savefig('HW8_g6')
plt.show()

# %%
plt.plot(1,1,'bx')
plt.plot(4,8,'ro')
plt.plot(5,7,'ro')
plt.plot(2,6,'ro')
plt.plot(6,4,'ro')
plt.plot(8,1,'ro')
plt.plot([0,10],[5,5],'g-')
plt.plot([3,3],[0,10],'b-')
plt.plot([0,10],[2,2],'r-')

plt.axis([0,10,0,10])
plt.title('AdaBoost Class')
plt.savefig('HW8_g7')
plt.show()
